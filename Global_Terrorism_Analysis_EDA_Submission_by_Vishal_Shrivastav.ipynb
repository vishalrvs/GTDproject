# %% [markdown]
# <a href="https://colab.research.google.com/github/vishalrvs/GTDproject/blob/main/Global_Terrorism_Analysis_EDA_Submission_by_Vishal_Shrivastav.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - GTDproject EDA

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Team
# ##### **Team Member 1 -** Vishal R Shrivastav
# ##### **Team Member 2 -** Arun Chaudhary
# ##### **Team Member 3 -** Nayana Salve

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The objective of this project is to conduct an exploratory data analysis (EDA) of the Global Terrorism Database (GTD), an open-source dataset that contains comprehensive information on both domestic and international terrorist attacks occurring globally from 1970 through 2017.
#
# Developed and maintained by the National Consortium for the Study of Terrorism and Responses to Terrorism (START) at the University of Maryland, the database encompasses details of over 180,000 recorded terrorist incidents. The project's principal aim is to dig deep into this expansive dataset, identify significant trends, patterns, and insights pertaining to terrorism-related activities, and present these discoveries visually for an enhanced understanding.
# A critical aspect of this project is the extensive use of Python libraries tailored for data analysis and visualization. The cornerstone of data manipulation, including loading the dataset, cleaning data, and executing sophisticated aggregation operations, will be the Pandas library.This powerful, high-performance tool offers efficient data structures and makes the handling of large datasets effortless.
# To facilitate advanced numerical operations and speed up computation, the project employs the NumPy library. Given its proficiency in handling multi-dimensional arrays and matrices, NumPy is the perfect companion for data processing operations.
#
# The project doesn't stop at numerical data analysis; it brings the extracted insights to life through vivid, informative visualizations, courtesy of the Matplotlib and Seaborn libraries. These libraries provide an array of visualization styles, enabling the display of data in ways that are both appealing and informative. From bar plots and scatter plots to histograms and heatmaps, the project will utilize a minimum of five different visualizations to reveal relationships between variables and provide a graphical representation of the dataset's characteristics.
# Exploring the GTD through this project will pave the way for an intricate understanding of terrorism patterns over the past decades. The goal is to unveil potential trends in attack frequency, most targeted countries, preferred methods of attack, types of weapons used, casualties, and the evolution of terrorist organizations, among other relevant dimensions.
# By examining these factors, the project aims to provide a detailed overview of global terrorism trends, informing counter-terrorism strategies and policies. Additionally, the findings may also help understand the characteristics of regions prone to attacks and the reasons behind their vulnerability.
# In conclusion, this project offers a data-driven exploration into the dark world of terrorism, aiming to shed light on the complex patterns hidden within the enormity of the GTD. The end product of this project will be an array of valuable insights that have the potential to contribute substantially to ongoing counter-terrorism efforts and inform future research in this field. The combination of data manipulation, numerical computation, and graphic visualization is expected to yield a robust and comprehensive exploration of the dataset, leading to substantial key findings pertaining to global terrorism.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/vishalrvs/GTDproject

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Using exploratory data analysis (EDA) techniques on the GTD, identify the hot zones of terrorism globally and discern the evolving patterns of terrorist activities. What insights related to security issues can be derived from this analysis that could be instrumental in shaping counterterrorism strategies?

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The business objective of this project is to leverage the data contained within the Global Terrorism Database (GTD to derive actionable insights into terrorist activities worldwide from 1970 to 2017. By conducting a comprehensive exploratory data analysis (EDA), the goal is to identify the key patterns, trends, and correlations related to global terrorism, thereby enabling better-informed decision-making for security analysts, policy-makers, and counter-terrorism agencies.
#
# Specifically, the objectives include:
#
# Identification of global "hot zones" for terrorist activities: By determining the most affected regions, we can better understand where resources might be best allocated to prevent future attacks.
#
# Analysis of frequency and intensity of attacks: Understanding how these have evolved over time can provide insights into the changing dynamics of terrorism and allow for more accurate risk assessments.
#
# Examination of methodologies and weapons used in attacks: This can shed light on the operational preferences of terrorist organizations and potentially provide early indicators of future threats.
#
# Assessment of casualty trends: This can help identify the most devastating types of attacks and allow for targeted response planning to minimize human loss.
#
# Unveiling patterns related to terrorist organizations: This can potentially aid in understanding their strategies, thereby supporting intelligence agencies in their counter-terrorism efforts.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
try:
    import warnings
    import numpy as np # To perform mathematical operations on arrays
    import pandas as pd # Manipulation with data by dataframes
    import seaborn as sbn # Used For visualization
    import matplotlib.pyplot as plt # Also used to visualize data (It act as core library for seaborn)
    warnings.simplefilter(action='ignore', category=FutureWarning)
except Exception as e:
    print(e)
else:
    print('Required Libraries successfully Imported')
# Out:
# Required Libraries successfully Imported

# %% [markdown]
# # Importing Library to mount drive for accesing dataset

# %%
try:
    from google.colab import drive # Library to mount drive in colaboratory environment
    drive.mount('/content/drive/')
except Exception as e:
    print(e)
else:
    print('Drive Monted Successfully')
# Out:
# Mounted at /content/drive/
# Drive Monted Successfully

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
# pandas library to create dataframe
# Used arguements - 'encoding' for proper loading in given encoding charset and low_memory to include all features
try:
    df_GTA = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Projects /Global Terrorism Analysis EDA/Global Terrorism Data.csv',encoding='ISO-8859-1',low_memory=False)
except Exception as e:
    print(e)
else:
    print('DataFrame created using csv')
# Out:
# DataFrame created using csv

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
try:
    print(df_GTA.head().to_string()) #Printing first five row
except Exception as e:
    print(e)
else:
    print('First five rows loaded to see Dataset First Look.')
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country         country_txt  region                   region_txt provstate           city   latitude   longitude  specificity  vicinity location summary  crit1  crit2  crit3  doubtterr  alternative alternative_txt  multiple  success  suicide  attacktype1                 attacktype1_txt  attacktype2 attacktype2_txt  attacktype3 attacktype3_txt  targtype1                targtype1_txt  targsubtype1                                      targsubtype1_txt                        corp1                  target1  natlty1         natlty1_txt  targtype2 targtype2_txt  targsubtype2 targsubtype2_txt corp2 target2  natlty2 natlty2_txt  targtype3 targtype3_txt  targsubtype3 targsubtype3_txt corp3 target3  natlty3 natlty3_txt                               gname gsubname gname2 gsubname2 gname3 gsubname3 motive  guncertain1  guncertain2  guncertain3  individual  nperps  nperpcap  claimed  claimmode claimmode_txt  claim2  claimmode2 claimmode2_txt  claim3  claimmode3 claimmode3_txt  compclaim  weaptype1 weaptype1_txt  weapsubtype1        weapsubtype1_txt  weaptype2 weaptype2_txt  weapsubtype2 weapsubtype2_txt  weaptype3 weaptype3_txt  weapsubtype3 weapsubtype3_txt  weaptype4 weaptype4_txt  weapsubtype4 weapsubtype4_txt  weapdetail  nkill  nkillus  nkillter  nwound  nwoundus  nwoundte  property  propextent propextent_txt  propvalue propcomment  ishostkid  nhostkid  nhostkidus  nhours  ndays divert kidhijcountry  ransom  ransomamt  ransomamtus  ransompaid  ransompaidus ransomnote  hostkidoutcome hostkidoutcome_txt  nreleased addnotes scite1 scite2 scite3 dbsource  INT_LOG  INT_IDEO  INT_MISC  INT_ANY related
# 0  197000000001   1970       7     2        NaN         0        NaN       58  Dominican Republic       2  Central America & Caribbean       NaN  Santo Domingo  18.456792  -69.951164          1.0         0      NaN     NaN      1      1      1        0.0          NaN             NaN       0.0        1        0            1                   Assassination          NaN             NaN          NaN             NaN         14  Private Citizens & Property          68.0                                        Named Civilian                          NaN             Julio Guzman     58.0  Dominican Republic        NaN           NaN           NaN              NaN   NaN     NaN      NaN         NaN        NaN           NaN           NaN              NaN   NaN     NaN      NaN         NaN                              MANO-D      NaN    NaN       NaN    NaN       NaN    NaN          0.0          NaN          NaN           0     NaN       NaN      NaN        NaN           NaN     NaN         NaN            NaN     NaN         NaN            NaN        NaN         13       Unknown           NaN                     NaN        NaN           NaN           NaN              NaN        NaN           NaN           NaN              NaN        NaN           NaN           NaN              NaN         NaN    1.0      NaN       NaN     0.0       NaN       NaN         0         NaN            NaN        NaN         NaN        0.0       NaN         NaN     NaN    NaN    NaN           NaN     0.0        NaN          NaN         NaN           NaN        NaN             NaN                NaN        NaN      NaN    NaN    NaN    NaN     PGIS        0         0         0        0     NaN
N          6    Explosives          16.0  Unknown Explosive Type        NaN           NaN           NaN              NaN        NaN           NaN           NaN              NaN        NaN           NaN           NaN              NaN   Explosive    NaN      NaN       NaN     NaN       NaN       NaN         1         NaN            NaN        NaN         NaN        0.0       NaN         NaN     NaN    NaN    NaN           NaN     0.0        NaN          NaN         NaN           NaN        NaN             NaN                NaN        NaN      NaN    NaN    NaN    NaN     PGIS       -9        -9         1        1     NaN
# 4  197001000003   1970       1     0        NaN         0        NaN      101               Japan       4                    East Asia   Fukouka        Fukouka  33.580412  130.396361          1.0         0      NaN     NaN      1      1      1       -9.0          NaN             NaN       0.0        1        0            7  Facility/Infrastructure Attack          NaN             NaN          NaN             NaN          7      Government (Diplomatic)          46.0                                     Embassy/Consulate                          NaN           U.S. Consulate    217.0       United States        NaN           NaN           NaN              NaN   NaN     NaN      NaN         NaN        NaN           NaN           NaN              NaN   NaN     NaN      NaN         NaN                             Unknown      NaN    NaN       NaN    NaN       NaN    NaN          0.0          NaN          NaN           0     NaN       NaN      NaN        NaN           NaN     NaN         NaN            NaN     NaN         NaN            NaN        NaN          8    Incendiary           NaN                     NaN        NaN           NaN           NaN              NaN        NaN           NaN           NaN              NaN        NaN           NaN           NaN              NaN  Incendiary    NaN      NaN       NaN     NaN       NaN       NaN         1         NaN            NaN        NaN         NaN        0.0       NaN         NaN     NaN    NaN    NaN           NaN     0.0        NaN          NaN         NaN           NaN        NaN             NaN                NaN        NaN      NaN    NaN    NaN    NaN     PGIS       -9        -9         1        1     NaN
# First five rows loaded to see Dataset First Look.

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
try:
    s = df_GTA.shape # Shape attribute to access number of rows and columns
except Exception as e:
    print(e)
else:
    print(f'We have {s[0]} rows and {s[1]} columns to analyze.')
# Out:
# We have 181691 rows and 135 columns to analyze.

# %% [markdown]
# *   We have 181691 rows  AND 135 columns to analyze

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
try:
    df_GTA.info(verbose=True,null_counts=True) # Here our dataset having large number of columns so we used extra arguments
except Exception as e:
    print(e)
else:
    print('Info of dataset loaded Successfully')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 135 columns):
#  #    Column              Non-Null Count   Dtype
# ---   ------              --------------   -----
#  0    eventid             181691 non-null  int64
#  1    iyear               181691 non-null  int64
#  2    imonth              181691 non-null  int64
#  3    iday                181691 non-null  int64
#  4    approxdate          9239 non-null    object
#  5    extended            181691 non-null  int64
#  6    resolution          2220 non-null    object
#  7    country             181691 non-null  int64
#  8    country_txt         181691 non-null  object
#  9    region              181691 non-null  int64
#  10   region_txt          181691 non-null  object
#  11   provstate           181270 non-null  object
#  12   city                181257 non-null  object
#  13   latitude            177135 non-null  float64
#  14   longitude           177134 non-null  float64
#  15   specificity         181685 non-null  float64
#  16   vicinity            181691 non-null  int64
#  17   location            55495 non-null   object
#  18   summary             115562 non-null  object
#  19   crit1               181691 non-null  int64
#  20   crit2               181691 non-null  int64
#  21   crit3               181691 non-null  int64
#  22   doubtterr           181690 non-null  float64
#  23   alternative         29011 non-null   float64
#  24   alternative_txt     29011 non-null   object
#  25   multiple            181690 non-null  float64
#  26   success             181691 non-null  int64
#  27   suicide             181691 non-null  int64
#  28   attacktype1         181691 non-null  int64
#  29   attacktype1_txt     181691 non-null  object
#  30   attacktype2         6314 non-null    float64
#  31   attacktype2_txt     6314 non-null    object
#  32   attacktype3         428 non-null     float64
#  33   attacktype3_txt     428 non-null     object
#  34   targtype1           181691 non-null  int64
#  35   targtype1_txt       181691 non-null  object
#  36   targsubtype1        171318 non-null  float64
#  37   targsubtype1_txt    171318 non-null  object
#  38   corp1               139141 non-null  object
#  39   target1             181055 non-null  object
#  40   natlty1             180132 non-null  float64
#  41   natlty1_txt         180132 non-null  object
#  42   targtype2           11144 non-null   float64
#  43   targtype2_txt       11144 non-null   object
#  44   targsubtype2        10685 non-null   float64
#  45   targsubtype2_txt    10685 non-null   object
#  46   corp2               10117 non-null   object
#  47   target2             11020 non-null   object
#  48   natlty2             10828 non-null   float64
#  49   natlty2_txt         10828 non-null   object
#  50   targtype3           1176 non-null    float64
#  51   targtype3_txt       1176 non-null    object
#  52   targsubtype3        1097 non-null    float64
#  53   targsubtype3_txt    1097 non-null    object
#  54   corp3               1026 non-null    object
#  55   target3             1175 non-null    object
#  56   natlty3             1147 non-null    float64
#  57   natlty3_txt         1147 non-null    object
#  58   gname               181691 non-null  object
#  59   gsubname            5890 non-null    object
#  60   gname2              2013 non-null    object
#  61   gsubname2           160 non-null     object
#  62   gname3              324 non-null     object
#  63   gsubname3           20 non-null      object
#  64   motive              50561 non-null   object
#  65   guncertain1         181311 non-null  float64
#  66   guncertain2         1955 non-null    float64
#  67   guncertain3         320 non-null     float64
#  68   individual          181691 non-null  int64
#  69   nperps              110576 non-null  float64
#  70   nperpcap            112202 non-null  float64
#  71   claimed             115571 non-null  float64
#  72   claimmode           19083 non-null   float64
#  73   claimmode_txt       19083 non-null   object
#  74   claim2              1890 non-null    float64
#  75   claimmode2          616 non-null     float64
#  76   claimmode2_txt      616 non-null     object
#  77   claim3              318 non-null     float64
#  78   claimmode3          133 non-null     float64
#  79   claimmode3_txt      133 non-null     object
#  80   compclaim           4839 non-null    float64
#  81   weaptype1           181691 non-null  int64
#  82   weaptype1_txt       181691 non-null  object
#  83   weapsubtype1        160923 non-null  float64
#  84   weapsubtype1_txt    160923 non-null  object
#  85   weaptype2           13127 non-null   float64
#  86   weaptype2_txt       13127 non-null   object
#  87   weapsubtype2        11542 non-null   float64
#  88   weapsubtype2_txt    11542 non-null   object
#  89   weaptype3           1863 non-null    float64
#  90   weaptype3_txt       1863 non-null    object
#  91   weapsubtype3        1693 non-null    float64
#  92   weapsubtype3_txt    1693 non-null    object
#  93   weaptype4           73 non-null      float64
#  94   weaptype4_txt       73 non-null      object
#  95   weapsubtype4        70 non-null      float64
#  96   weapsubtype4_txt    70 non-null      object
#  97   weapdetail          114021 non-null  object
#  98   nkill               171378 non-null  float64
#  99   nkillus             117245 non-null  float64
#  100  nkillter            114733 non-null  float64
#  101  nwound              165380 non-null  float64
#  102  nwoundus            116989 non-null  float64
#  103  nwoundte            112548 non-null  float64
#  104  property            181691 non-null  int64
#  105  propextent          64065 non-null   float64
#  106  propextent_txt      64065 non-null   object
#  107  propvalue           38989 non-null   float64
#  108  propcomment         57959 non-null   object
#  109  ishostkid           181513 non-null  float64
#  110  nhostkid            13572 non-null   float64
#  111  nhostkidus          13517 non-null   float64
#  112  nhours              4063 non-null    float64
#  113  ndays               8124 non-null    float64
#  114  divert              324 non-null     object
#  115  kidhijcountry       3305 non-null    object
#  116  ransom              77381 non-null   float64
#  117  ransomamt           1350 non-null    float64
#  118  ransomamtus         563 non-null     float64
#  119  ransompaid          774 non-null     float64
#  120  ransompaidus        552 non-null     float64
#  121  ransomnote          514 non-null     object
#  122  hostkidoutcome      10991 non-null   float64
#  123  hostkidoutcome_txt  10991 non-null   object
#  124  nreleased           10400 non-null   float64
#  125  addnotes            28289 non-null   object
#  126  scite1              115500 non-null  object
#  127  scite2              76933 non-null   object
#  128  scite3              43516 non-null   object
#  129  dbsource            181691 non-null  object
#  130  INT_LOG             181691 non-null  int64
#  131  INT_IDEO            181691 non-null  int64
#  132  INT_MISC            181691 non-null  int64
#  133  INT_ANY             181691 non-null  int64
#  134  related             25038 non-null   object
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB
# Info of dataset loaded Successfully

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
try:
    print('Duplicate count of rows: ',len(df_GTA[df_GTA.duplicated()]))# We use duplicated method which return boolean indexing
except Exception as e:
    print(e)
# Out:
# Duplicate count of rows:  0

# %% [markdown]
# *   We dont have any duplicate rows

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
try:
    missing_data = df_GTA.isnull()
    missing_counts = missing_data.sum()
    print('Missing value counts per column:\n',missing_counts.to_string())
except Exception as e:
    print(e)
# Out:
# Missing value counts per column:
#  eventid                    0
# iyear                      0
# imonth                     0
# iday                       0
# approxdate            172452
# extended                   0
# resolution            179471
# country                    0
# country_txt                0
# region                     0
# region_txt                 0
# provstate                421
# city                     434
# latitude                4556
# longitude               4557
# specificity                6
# vicinity                   0
# location              126196
# summary                66129
# crit1                      0
# crit2                      0
# crit3                      0
# doubtterr                  1
# alternative           152680
# alternative_txt       152680
# multiple                   1
# success                    0
# suicide                    0
# attacktype1                0
# attacktype1_txt            0
# attacktype2           175377
# attacktype2_txt       175377
# attacktype3           181263
# attacktype3_txt       181263
# targtype1                  0
# targtype1_txt              0
# targsubtype1           10373
# targsubtype1_txt       10373
# corp1                  42550
# target1                  636
# natlty1                 1559
# natlty1_txt             1559
# targtype2             170547
# targtype2_txt         170547
# targsubtype2          171006
# targsubtype2_txt      171006
# corp2                 171574
# target2               170671
# natlty2               170863
# natlty2_txt           170863
# targtype3             180515
# targtype3_txt         180515
# targsubtype3          180594
# targsubtype3_txt      180594
# corp3                 180665
# target3               180516
# natlty3               180544
# natlty3_txt           180544
# gname                      0
# gsubname              175801
# gname2                179678
# gsubname2             181531
# gname3                181367
# gsubname3             181671
# motive                131130
# guncertain1              380
# guncertain2           179736
# guncertain3           181371
# individual                 0
# nperps                 71115
# nperpcap               69489
# claimed                66120
# claimmode             162608
# claimmode_txt         162608
# claim2                179801
# claimmode2            181075
# claimmode2_txt        181075
# claim3                181373
# claimmode3            181558
# claimmode3_txt        181558
# compclaim             176852
# weaptype1                  0
# weaptype1_txt              0
# weapsubtype1           20768
# weapsubtype1_txt       20768
# weaptype2             168564
# weaptype2_txt         168564
# weapsubtype2          170149
# weapsubtype2_txt      170149
# weaptype3             179828
# weaptype3_txt         179828
# weapsubtype3          179998
# weapsubtype3_txt      179998
# weaptype4             181618
# weaptype4_txt         181618
# weapsubtype4          181621
# weapsubtype4_txt      181621
# weapdetail             67670
# nkill                  10313
# nkillus                64446
# nkillter               66958
# nwound                 16311
# nwoundus               64702
# nwoundte               69143
# property                   0
# propextent            117626
# propextent_txt        117626
# propvalue             142702
# propcomment           123732
# ishostkid                178
# nhostkid              168119
# nhostkidus            168174
# nhours                177628
# ndays                 173567
# divert                181367
# kidhijcountry         178386
# ransom                104310
# ransomamt             180341
# ransomamtus           181128
# ransompaid            180917
# ransompaidus          181139
# ransomnote            181177
# hostkidoutcome        170700
# hostkidoutcome_txt    170700
# nreleased             171291
# addnotes              153402
# scite1                 66191
# scite2                104758
# scite3                138175
# dbsource                   0
# INT_LOG                    0
# INT_IDEO                   0
# INT_MISC                   0
# INT_ANY                    0
# related               156653

# %% [markdown]
# *   Before plotting heatmap of missing data in features we are dropping some columns which are too redundant and negligible data. Some columns dont have sufficient amount of data to be in dataset.

# %%
# Here we are assigning only the columns which have to be perform operation
# Instead of drop we are assigning selected columns which are going to be part of project
try:
    df_GTA = df_GTA[['iyear', 'imonth', 'iday','country','country_txt', 'region','region_txt', 'city', 'latitude', 'longitude', 'vicinity', 'crit1', 'crit2', 'crit3', 'doubtterr',\
                    'success', 'suicide', 'attacktype1','attacktype1_txt','targtype1', 'targtype1_txt', 'individual', 'weaptype1','weaptype1_txt', 'nkill', 'nkillus', 'nkillter',\
                    'nwound', 'nwoundus', 'nwoundte', 'property','propextent', 'propextent_txt', 'ishostkid', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY']]
    missing_data = df_GTA.isnull()
except Exception as e:
    print(e)

# %%
# Visualizing the missing values by heatmap
try:
    ax , fig = plt.subplots(figsize=(15,10))
    sbn.heatmap(missing_data.T) # Used heatmap of
    plt.title('Visualizing Missing Data')
    plt.show()
except Exception as e:
    print(e)

# %% [markdown]
# * By above visualization we can see that the light coloured part shows missing data and Blue coloured parts are filled data

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# *   Dataset is about Global Terorism Data. Dataset comprises columns about attacks, date, year, month, attack type informations which are very helpful to analyze about the terorrism. Why it happens. How can we ready to tackle this type of situations,. etc.
#
#
# *    Initially Dataset having 181691 rows and 135 columns. Most of these columns are incomplete. So, we dicided to drop.
#
# *   After droping those columns we have 38 columns to start EDA.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
try:
    columns_df_GTA = np.array(df_GTA.columns) # Storing in array for later use
    print('Columns list in the Final dataset which is going to be used: ',columns_df_GTA)
except Exception as e:
    print(e)
# Out:
# Columns list in the Final dataset which is going to be used:  ['iyear' 'imonth' 'iday' 'country' 'country_txt' 'region' 'region_txt'
#  'city' 'latitude' 'longitude' 'vicinity' 'crit1' 'crit2' 'crit3'
# ishostkid    181513.0     0.059054       0.461244 -9.000000e+00     0.000000     0.000000     0.000000     1.000000
# INT_LOG      181691.0    -4.543731       4.543547 -9.000000e+00    -9.000000    -9.000000     0.000000     1.000000
# INT_IDEO     181691.0    -4.464398       4.637152 -9.000000e+00    -9.000000    -9.000000     0.000000     1.000000
# INT_MISC     181691.0     0.090010       0.568457 -9.000000e+00     0.000000     0.000000     0.000000     1.000000
# INT_ANY      181691.0    -3.945952       4.691325 -9.000000e+00    -9.000000     0.000000     0.000000     1.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# *   'iyear'  - This field contains the year in which the incident occurred
#
# *   'imonth' - The field will record the month when the incident was initiated.
#
# *   'iday' -   This field contains the numeric day of the month on which
#  incident occurred
#
# *  'country' - This field identifies the country ID where incident occurred.
#
# *  'country_txt' - This field identifies the country text or incident occurred.
#
# *  'region' - This field identifies the region ID where incident occurred.
#
# *   'region_txt'- This field identifies the region text.
#
# *   'city' - This field contains the name of city,village, or town in which the
# incident occurred
#
# *   'latitude' - This field record the latitude (based on WGS1984 standards)
# of the city in which the event occurred
#
# *   'longitude'- This field records the longitude (based on WGS1984 standards)
# of the city in which event is occurred
#
#
# *   'vicinity' -
# 1 = "yes" the incident occurred in the immediate vicinity of the city
# 0 = "No" the incident in the city itself
#
# *  'crit1' -  The violent act must be aimed at attaining a political, economic, religious, or social goal. This criterion is not satisfied in those cases where the perpetrator(s) acted out of a pure profit motive or from an idiosyncratic personal motive unconnected with broader societal change.
#   1 = "Yes" The incident meets Criterion 1.
#   0 = "No" The incident does not meet Criterion 1
#
# *  'crit2' - To satisfy this criterion there must be evidence of an intention to coerce, intimidate, or convey some other message to a larger audience (or audiences) than the immediate victims. Such evidence can include (but is not limited to) the following: pre- or postattack statements by the perpetrator(s), past behavior by the perpetrators, or the particular nature of the target/victim, weapon, or attack type
#   1 = "Yes" The incident meets Criterion 2.
#   0 = "No" The incident does not meet Criterion 2 or no indication.
#
# *  'crit3' - The action is outside the context of legitimate warfare activities, insofar as it targets non-combatants (i.e. the act must be outside the parameters permitted by international humanitarian law as reflected in the Additional Protocol to the Geneva Conventions of 12 August 1949 and elsewhere).
#   1 = "Yes" The incident meets Criterion 3.
#   0 = "No" The incident does not meet Criterion 3
#
# *  'doubtterr' - 1 = "Yes" There is doubt as to whether the incident is an act of terrorism. 0 = "No" There is essentially no doubt as to whether the incident is an act of terrorism.
#
# * 'success' - , Attack is successful if any of the attack types are successful, with the exception of assassinations, which are only successful if the intended target is killed.
#   1 = "Yes" The incident was successful.
#   0 = "No" The incident was not successful.
#
# *  'suicide' - This variable is coded “Yes” in those cases where there is evidence that the perpetrator did not intend to escape from the attack alive.
#   1 = "Yes" The incident was a suicide attack.
#   0 = "No" There is no indication that the incident was a suicide attack.
#
# *  'attacktype1_txt' -  It consists of nine categories, which are defined below.
#    1 = ASSASSINATION (An act whose primary objective is to kill one or more specific, prominent individuals. )
#    2 = ARMED ASSAULT (An attack whose primary objective is to cause physical harm or death directly to human beings by use of a firearm, incendiary, or sharp instrument (knife, etc.))
#    3 = BOMBING/EXPLOSION (An attack where the primary effects are caused by an energetically unstable material undergoing rapid decomposition and releasing a pressure wave that causes physical damage to the surrounding environment.)
#    4 = HIJACKING (An act whose primary objective is to take control of a vehicle such as an aircraft, boat, bus, etc.)
#    5 = HOSTAGE TAKING (BARRICADE INCIDENT) (An act whose primary objective is to take control of hostages for the purpose of achieving a political objective through concessions or through disruption of normal operations)
#    6 = HOSTAGE TAKING (KIDNAPPING) (An act whose primary objective is to take control of hostages for the purpose of achieving a political objective through concessions or through disruption of normal operations.)
#    7 = FACILITY / INFRASTRUCTURE ATTACK (An act, excluding the use of an explosive, whose primary objective is to cause damage to a non-human target, such as a building, monument, train, pipeline, etc)
#    8 = UNARMED ASSAULT (An attack whose primary objective is to cause physical harm or death directly to human beings by any means other than explosive, firearm, incendiary, or sharp instrument(knife, etc.).)
#    9 = UNKNOWN (The attack type cannot be determined from the available information.)
#
# *  'targtype1_txt' - Target/Victim Information
#   1 = BUSINESS
#   2 = GOVERNMENT (GENERAL)
#   3 = POLICE
#   4 = MILITARY
#   5 = ABORTION RELATED
#   6 = AIRPORTS & AIRCRAFT
#   7 = GOVERNMENT (DIPLOMATIC)
#   8 = EDUCATIONAL INSTITUTION
#   9 = FOOD OR WATER SUPPLY
#   10 = JOURNALISTS & MEDIA
#
# *  'individual' -
#   1 = "Yes" The perpetrator(s) were identified by name (or specific unnamed minors) and not known to be affiliated with a group or organization.
#   0 = "No" The perpetrator(s) were not identified as unaffiliated individuals (i.e. the perpetrators were either not identified by name, or were known to be affiliated with a group or organization).
#
# *  'weaptype1_txt' - The weapon type used in attack
#   1 = Biological
#   2 = Chemical
#   3 = Radiological (A weapon whose components are produced from radioactive materials that emit ionizing radiation and can take many forms.)
#   4 = Nuclear
#   5 = Firearms (A weapon which is capable of firing a projectile using an explosive charge as a propellant.)
#   6 = Explosives
#   7 = Fake Weapons
#   8 = Incendiary (A weapon that is capable of catching fire, causing fire, or burning readily and produces intensely hot fire when exploded.)
#   9 = Melee (A weapon—targeting people rather than property—that does not involve a projectile in which the user and target are in contact with it simultaneously.)
#   10 = Vehicle (An automobile that is used in an incident that does not incorporate the use of explosives such as a car bomb or truck bomb.)
#   11 = Sabotage Equipment
#   12 = Other (A weapon that has been identified but does not fit into one of the above categories.)
#   13 = Unknown (The weapon type cannot be determined from the available information.)
#
# *  'nkill' - Total Number of Fatalities (This field stores the number of total confirmed fatalities for the incident. The number includes all victims and attackers who died as a direct result of the incident. )
#
# *  'nkillus' - Number of US Fatalities (This field records the number of U.S. citizens who died as a result of the incident, and follows the conventions of “Total Number of Fatalities” described above)
#
# *  'nkillter' - Number of Perpetrator Fatalities (Limited to only perpetrator fatalities, this field follows the conventions of the “Total Number of Fatalities” field described above)
#
# * 'nwound' - This field records the number of confirmed non-fatal injuries to both perpetrators and victims.
#
# * 'nwoundus' - This field records the number of confirmed non-fatal injuries to U.S. citizens, both perpetrators
# and victims.
#
#
# * 'nwoundte' - Conventions follow the “Number of Perpetrator Fatalities” field described above.
#
# * 'property' - “Yes” appears if there is evidence of property damage from the incident.
# 1 = "Yes" The incident resulted in property damage.
# 0 = "No" The incident did not result in property damage.
#  -9 = "Unknown" It is unknown if the incident resulted in property damage
#
# * 'propextent' - If “Property Damage?” is “Yes,” then one of the following four categories describes the extent
# of the property damage:
# 1 = Catastrophic (likely ≥ $1 billion)
# 2 = Major (likely ≥ $1 million but < $1 billion)
# 3 = Minor (likely < $1 million)
# 4 = Unknown
#
# * 'propextent_txt' - If “Property Damage?” is “Yes,” then one of the following four categories describes the extent
# of the property damage:
# 1 = Catastrophic (likely ≥ $1 billion)
# 2 = Major (likely ≥ $1 million but < $1 billion)
# 3 = Minor (likely < $1 million)
# 4 = Unknown
#
# * 'ishostkid' - This field records whether or not the victims were taken hostage.
#
# * 'INT_LOG' - This variable is based on a comparison between the nationality of the perpetrator group and
#
# * 'INT_IDEO' - This variable is based on a comparison between the nationality of the perpetrator group and
# the nationality of the target(s)/victim(s). It indicates whether a perpetrator group attacked a
# target of a different nationality.
#
# * 'INT_MISC' -  This variable is based on a comparison between the location of the attack and the nationality of
# the target(s)/victim(s). It indicates whether a perpetrator group attacked a target of a different
# nationality.
#
#
# * 'INT_ANY' -
#  1 = "Yes" The attack was international on any of the dimensions described above
#  (logistically, ideologically, miscellaneous)
#  0 = "No" The attack was domestic on all of the dimensions described above
#  (logistically, ideologically, miscellaneous)
#  -9 = "Unknown" It is unknown if the attack was international or domestic; the value for one or more dimensions is unknown.Answer

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
try:
    for variable in columns_df_GTA:
        print(f'Unique values for {variable}')
        print(df_GTA[variable].unique())
        print('*'*50)
except Exception as e:
    print(e)
# Out:
# Unique values for iyear
# [1970 1971 1972 1973 1974 1975 1976 1977 1978 1979 1980 1981 1986 1982
#  1983 1984 1985 1987 1988 1989 1990 1991 1992 1994 1995 1996 1997 1998
#  1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012
#  2013 2014 2015 2016 2017]
# **************************************************
# Unique values for imonth
# [ 7  0  1  2  3  4  5  6  8  9 10 11 12]
# **************************************************
# Unique values for iday
# [ 2  0  1  3  6  8  9 10 11 12 13 14 15 19 20 21 22 25 26 27 28 30 31  4
#   7 16 17 18 23 24  5 29]
# **************************************************
# Unique values for country
# [  58  130  160   78  101  217  218   98  499   65   83  222  362  199
#   102  185   30   60   11  110   96  209  158   94  603   45   26  145
#   142   21   38   14  153  230  198   49  406   36   97  161  201  156
#   106  155   15  236   92   69  428   31  604  605  162    6   61  205
#    87  195  136   53  138    4  159   43   88  235   59  144  121  178
#    29  100   42  377    7  200  184  215  183  104   95  182  203  186
#   139   17  147   20  207   19    8  128  173   56   93  124  403  359
#    55  349   86  137  208  213  151  111   72  113   18   89  174  231
#    84   80  532   22   81  127  221    5   41  176   57  164   32  196
#   197  116   91   70   66   33  143  166  146  141  204   68   67   76
#   122  129   90  108  157   44  112   47  123   75  228  168  177   37
#    51   50   74   16  119  115   34  214  132   12  167   99  103   10
#    28   62  202  120  219  109   64  223   46   23  179  118  226   35
#    54  180   73  149   63  189   71  117  107  220  229 1003  181  347
#   190   85 1002  422  210  175   25 1001 1004]
# **************************************************
# Unique values for country_txt
# ['Dominican Republic' 'Mexico' 'Philippines' 'Greece' 'Japan'
#  'United States' 'Uruguay' 'Italy' 'East Germany (GDR)' 'Ethiopia'
#  'Guatemala' 'Venezuela' 'West Germany (FRG)' 'Switzerland' 'Jordan'
#  'Spain' 'Brazil' 'Egypt' 'Argentina' 'Lebanon' 'Ireland' 'Turkey'
#  'Paraguay' 'Iran' 'United Kingdom' 'Colombia' 'Bolivia' 'Nicaragua'
#  'Netherlands' 'Belgium' 'Canada' 'Australia' 'Pakistan' 'Zambia' 'Sweden'
#  'Costa Rica' 'South Yemen' 'Cambodia' 'Israel' 'Poland' 'Taiwan' 'Panama'
#  'Kuwait' 'West Bank and Gaza Strip' 'Austria' 'Czechoslovakia' 'India'
#  'France' 'South Vietnam' 'Brunei' 'Zaire'
#  "People's Republic of the Congo" 'Portugal' 'Algeria' 'El Salvador'
#  'Thailand' 'Haiti' 'Sudan' 'Morocco' 'Cyprus' 'Myanmar' 'Afghanistan'
#  'Peru' 'Chile' 'Honduras' 'Yugoslavia' 'Ecuador' 'New Zealand' 'Malaysia'
#  'Singapore' 'Botswana' 'Jamaica' 'Chad' 'North Yemen' 'Andorra' 'Syria'
#  'South Korea' 'United Arab Emirates' 'South Africa' 'Kenya' 'Iraq'
#  'Somalia' 'Tanzania' 'Sri Lanka' 'Namibia' 'Bahamas' 'Nigeria' 'Barbados'
#  'Trinidad and Tobago' 'Bangladesh' 'Angola' 'Mauritania' 'Saudi Arabia'
#  'Djibouti' 'Indonesia' 'Malta' 'Rhodesia' 'Soviet Union' 'Denmark'
#  'Western Sahara' 'Guyana' 'Mozambique' 'Tunisia' 'Uganda' 'Norway'
#  'Lesotho' 'Gabon' 'Libya' 'Bahrain' 'Hong Kong' 'Senegal' 'Zimbabwe'
#  'Guinea' 'Grenada' 'New Hebrides' 'Belize' 'Guadeloupe' 'Martinique'
#  'Vatican City' 'Albania' 'Central African Republic' 'Seychelles'
#  'Dominica' 'Qatar' 'Bulgaria' 'Suriname' 'Swaziland' 'Luxembourg'
#  'Iceland' 'French Guiana' 'Falkland Islands' 'Burkina Faso'
#  'New Caledonia' 'Romania' 'Niger' 'Nepal' 'Togo' 'Finland' 'Fiji' 'Ghana'
#  'Maldives' 'Mauritius' 'Hungary' 'Laos' 'Papua New Guinea' 'China'
#  'Liberia' 'Republic of the Congo' 'Mali' 'Germany' 'Yemen' 'Rwanda'
#  'Sierra Leone' 'Cameroon' 'Cuba' 'Croatia' 'Georgia' 'Azerbaijan'
#  'Madagascar' 'Lithuania' 'Burundi' 'Ukraine' 'Moldova' 'Armenia' 'Russia'
#  'Ivory Coast' 'Kazakhstan' 'Antigua and Barbuda' 'Bosnia-Herzegovina'
#  'Equatorial Guinea' 'Tajikistan' 'Malawi' 'Uzbekistan' 'Latvia' 'Estonia'
#  'Vietnam' 'Comoros' 'Benin' 'Slovak Republic' 'Macedonia'
#  'Wallis and Futuna' 'Belarus' 'Czech Republic' 'Slovenia' 'Gambia'
#  'North Korea' 'Eritrea' 'St. Kitts and Nevis' 'French Polynesia' 'Macau'
#  'Kyrgyzstan' 'Vanuatu' 'Democratic Republic of the Congo' 'Kosovo'
#  'Solomon Islands' 'East Timor' 'St. Lucia' 'Guinea-Bissau' 'Montenegro'
#  'International' 'Turkmenistan' 'Serbia-Montenegro' 'Bhutan' 'Serbia'
#  'South Sudan']
# **************************************************
# Unique values for region
# [ 2  1  5  8  4  3  9 11 10 12  6  7]
# **************************************************
# Unique values for region_txt
# ['Central America & Caribbean' 'North America' 'Southeast Asia'
#  'Western Europe' 'East Asia' 'South America' 'Eastern Europe'
#  'Sub-Saharan Africa' 'Middle East & North Africa' 'Australasia & Oceania'
#  'South Asia' 'Central Asia']
# **************************************************
# Unique values for city
# ['Santo Domingo' 'Mexico city' 'Unknown' ... 'Hungrum' 'Ceelka Geelow'
#  'Kubentog']
# **************************************************
# Unique values for latitude
# [18.456792 19.371887 15.478598 ...  2.359673 35.407278  6.900742]
# **************************************************
# Unique values for longitude
# [-69.951164 -99.086624 120.599741 ...  45.385034  35.942679 124.437908]
# **************************************************
# Unique values for vicinity
# [ 0  1 -9]
# **************************************************
# Unique values for crit1
# [1 0]
# **************************************************
# Unique values for crit2
# [1 0]
# **************************************************
# Unique values for crit3
# [1 0]
# **************************************************
# Unique values for doubtterr
# [ 0. -9.  1. nan]
# **************************************************
# Unique values for success
# [1 0]
# **************************************************
# Unique values for suicide
# [0 1]
# **************************************************
# Unique values for attacktype1
# [1 6 3 7 2 4 9 8 5]
# **************************************************
# Unique values for attacktype1_txt
# ['Assassination' 'Hostage Taking (Kidnapping)' 'Bombing/Explosion'
#  'Facility/Infrastructure Attack' 'Armed Assault' 'Hijacking' 'Unknown'
#  'Unarmed Assault' 'Hostage Taking (Barricade Incident)']
# **************************************************
# Unique values for targtype1
# [14  7 10  3 21  4  2  6  1  8 22 15 20 19 18 12 16  9 17 13 11  5]
# **************************************************
# Unique values for targtype1_txt
# ['Private Citizens & Property' 'Government (Diplomatic)'
#  'Journalists & Media' 'Police' 'Utilities' 'Military'
#  'Government (General)' 'Airports & Aircraft' 'Business'
#  'Educational Institution' 'Violent Political Party'
#  'Religious Figures/Institutions' 'Unknown' 'Transportation' 'Tourists'
#  'NGO' 'Telecommunication' 'Food or Water Supply'
#  'Terrorists/Non-State Militia' 'Other' 'Maritime' 'Abortion Related']
# **************************************************
# Unique values for individual
# [0 1]
# **************************************************
# Unique values for weaptype1
# [13  6  8  5  2  9 11 10  7  3 12  1]
# **************************************************
# Unique values for weaptype1_txt
# ['Unknown' 'Explosives' 'Incendiary' 'Firearms' 'Chemical' 'Melee'
#  'Sabotage Equipment'
#  'Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs
#  3.860e+02 3.910e+02 1.100e+02 1.490e+02 8.900e+01 9.100e+01 1.190e+02
#  7.700e+01 1.180e+02 6.700e+01 1.700e+02 1.940e+02 1.920e+02 2.270e+02
#  2.600e+02 4.000e+03 1.800e+02 1.840e+02 9.900e+01 9.400e+01 1.370e+02
#  8.190e+03 8.191e+03 1.710e+02 1.210e+02 1.030e+02 1.620e+02 1.970e+02
#  1.510e+02 2.240e+02 1.340e+02 2.330e+02 1.670e+02 4.500e+02 2.160e+02
#  1.450e+02 6.300e+01 7.270e+02 1.820e+02 1.590e+02 1.080e+02 1.280e+02
#  3.400e+02 1.630e+02 5.420e+02 8.700e+01 1.550e+02 8.170e+02 2.570e+02
#  1.480e+02 1.230e+02 2.460e+02 1.270e+02 3.470e+02 1.780e+02 1.680e+02
#  2.070e+02 1.830e+02 1.170e+02 7.500e+02 1.470e+02 1.001e+03 9.300e+01
#  1.540e+02 2.350e+02 1.580e+02 2.110e+02 1.160e+02 2.760e+02 5.520e+02
#  3.600e+02 1.130e+02 1.570e+02 1.750e+02 3.010e+02 1.310e+02 4.000e+02
#  3.700e+02 8.500e+00 1.690e+02 2.010e+02 1.110e+02 1.430e+02 1.530e+02
#  1.240e+02 7.900e+01 2.700e+02 1.520e+02 2.960e+02 2.450e+02 1.500e+03
#  3.510e+02 6.000e+02 4.330e+02 1.770e+02 4.910e+02 4.050e+02 8.510e+02
#  3.160e+02]
# **************************************************
# Unique values for nwoundus
# [ nan   0.   1.   2.   7.  17.   5.   3.  10.  12.  20.  27.   8.  50.
#    4.  36.  11.  22.   9.  75.  25.  18. 751.  14.  64.   6.  15. 650.
#   78.  37. 109.  19.  24.  38.  33.  13.  57.  60.  31.  77. 101. 151.
#   16.  48.  29.]
# **************************************************
# Unique values for nwoundte
# [ nan   0.   1.   4.   2.   3.   5.   6.  50.  10.  16.  20.   9.  13.
#   11. 200.   7.  15.  31.   8.  12.  25.  30.  38.  14.  21.  24.  18.
#   62.  17. 150.  22.  23.  33.  19.  40.  51. 101.  60.  35.  53.  26.
#  100.  49.  27.]
# **************************************************
# Unique values for property
# [ 0  1 -9]
# **************************************************
# Unique values for propextent
# [nan  3.  2.  4.  1.]
# **************************************************
# Unique values for propextent_txt
# [nan 'Minor (likely < $1 million)'
#  'Major (likely >= $1 million but < $1 billion)' 'Unknown'
#  'Catastrophic (likely >= $1 billion)']
# **************************************************
# Unique values for ishostkid
# [ 0.  1. nan -9.]
# **************************************************
# Unique values for INT_LOG
# [ 0 -9  1]
# **************************************************
# Unique values for INT_IDEO
# [ 0  1 -9]
# **************************************************
# Unique values for INT_MISC
# [ 0  1 -9]
# **************************************************
# Unique values for INT_ANY
# [ 0  1 -9]
# **************************************************

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# * all columns datatypes

# %%
try:
    print('Columns with their datatypes: \n',df_GTA.dtypes) #Used dtype propery of dataframe
except Exception as e:
    print(e)
# Out:
# Columns with their datatypes:
#  iyear                int64
# imonth               int64
# iday                 int64
# country              int64
# country_txt         object
# region               int64
# region_txt          object
# city                object
# latitude           float64
# longitude          float64
# vicinity             int64
# crit1                int64
# crit2                int64
# crit3                int64
# doubtterr          float64
# success              int64
# suicide              int64
# attacktype1          int64
# attacktype1_txt     object
# targtype1            int64
# targtype1_txt       object
# individual           int64
# weaptype1            int64
# weaptype1_txt       object
# nkill              float64
# nkillus            float64
# nkillter           float64
# nwound             float64
# nwoundus           float64
# nwoundte           float64
# property             int64
# propextent         float64
# propextent_txt      object
# ishostkid          float64
# INT_LOG              int64
# INT_IDEO             int64
# INT_MISC             int64
# INT_ANY              int64
# dtype: object

# %% [markdown]
# *  installing and importing pandarallel library to perform apply functions with multiprocessing functionality with initialization of 2 workers.

# %%
try:

    # !pip install pandarallel
    from pandarallel import pandarallel
    pandarallel.initialize(progress_bar=True,nb_workers=2)
except Exception as e:
    print(e)
# Out:
# Collecting pandarallel
#   Downloading pandarallel-1.6.5.tar.gz (14 kB)
#   Preparing metadata (setup.py) ... done
# Collecting dill>=0.3.1 (from pandarallel)
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1 in /usr/local/lib/python3.10/dist-packages (from pandarallel) (1.5.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from pandarallel) (5.9.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1->pandarallel) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1->pandarallel) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1->pandarallel) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1->pandarallel) (1.16.0)
# Building wheels for collected packages: pandarallel
#   Building wheel for pandarallel (setup.py) ... done
#   Created wheel for pandarallel: filename=pandarallel-1.6.5-py3-none-any.whl size=16677 sha256=f5cb144fa059d947a3b73a5f111389fda97de249c862ca58d23e1cc9a7d62e46
#   Stored in directory: /root/.cache/pip/wheels/50/4f/1e/34e057bb868842209f1623f195b74fd7eda229308a7352d47f
# Successfully built pandarallel
# Installing collected packages: dill, pandarallel
# Successfully installed dill-0.3.6 pandarallel-1.6.5
# INFO: Pandarallel will run on 2 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %% [markdown]
# * Generating a date column derived from 'iyear', 'imonth','iday'

# %%
try:

    def create_date(x):
        if(x['iyear'] != 0 and x['imonth'] != 0 and x['iday'] != 0):
            d = '/'.join([str(x['iday']) , str(x['imonth']) , str(x['iyear'])])
        else:
            d= np.nan
        return d
    df_GTA['idate'] = df_GTA[['iyear', 'imonth','iday']].parallel_apply(create_date,axis=1) # parallel_apply to save time
except Exception as e:
    print(e)
else:
    print('Column created in Dataframe having named as idate')
# print(df_GTA['idate'])
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=90846), Label(value='0 / 90846')))…
# Column created in Dataframe having named as idate

# %%
try:
    df_GTA['idate'] = pd.to_datetime(df_GTA['idate'],format='%d/%m/%Y') # Changing datatype to date
except Exception as e:
    print(e)
else:
    print('Data type changed to datetime format.')
# df_GTA['imonth'].value_counts()
# Out:
# Data type changed to datetime format.

# %%
try:
    print('Datatype of idate: ',df_GTA['idate'].dtype) #on a big endian machine, np.dtype('datetime64[ns]') would equal np.dtype('>M8[ns]')
    print('Total null values in idate: ',df_GTA['idate'].isnull().sum())
except Exception as e:
    print(e)
# Out:
# Datatype of idate:  datetime64[ns]
# Total null values in idate:  891

# %%
print(df_GTA.idate.head(20).to_string())
# Out:
# 0    1970-07-02
# 1           NaT
# 2           NaT
# 3           NaT
# 4           NaT
# 5    1970-01-01
# 6    1970-01-02
# 7    1970-01-02
# 8    1970-01-02
# 9    1970-01-03
# 10   1970-01-01
# 11   1970-01-06
# 12   1970-01-08
# 13   1970-01-09
# 14   1970-01-09
# 15   1970-01-10
# 16   1970-01-11
# 17   1970-01-12
# 18   1970-01-12
# 19   1970-01-13

# %% [markdown]
# *  By above data it is cleared that day or month are unknown, maximum cases are related to government employess. So we take decision to not to drop and fill missing values

# %% [markdown]
# *  Analyzing and manipulating 'City' because it has null values and different datatype

# %%
# Write your code to make your dataset analysis ready.
# Analyzing 'city'
try:
    null_valuecount_to_fill = df_GTA['city'].isnull().sum() # counting null values
    print('Total Null values in city:', null_valuecount_to_fill)
    df_GTA['city'] = df_GTA['city'].fillna('N/A') # filled and assigned to the original dataset
    print(df_GTA['city'].dtype) #printing datatype
except Exception as e:
    print(e)
else:
    print('Missing values filled with N/A. Datatype is okay to proceed with City column.')
# Out:
# Total Null values in city: 434
# object
# Missing values filled with N/A. Datatype is okay to proceed with City column.

# %% [markdown]
# * Analyzing and manipulating 'latitude' because it has null values and different datatype

# %%
# Write your code to make your dataset analysis ready.
# Analyzing 'latitude'
try:
    null_valuecount_to_fill = df_GTA['latitude'].isnull().sum() # counting null values
    print('Total Null values in latitude:', null_valuecount_to_fill)
    df_GTA['latitude'] = df_GTA['latitude'].fillna(-200) # filled and assigned to the original dataset
    print(df_GTA['latitude'].dtype) #printing datatype
except Exception as e:
    print(e)
else:
    print('Missing values filled with -200. Datatype is okay to proceed with latitude column.')
# Out:
# Total Null values in latitude: 4556
# float64
# Missing values filled with -200. Datatype is okay to proceed with latitude column.

# %% [markdown]
# * Analyzing and manipulating 'longitude' because it has null values and different datatype

# %%
# Analyzing longitude
try:
    null_valuecount_to_fill = df_GTA['longitude'].isnull().sum() # counting null values
    print('Total Null values in longitude:', null_valuecount_to_fill)
    df_GTA['longitude'] = df_GTA['longitude'].fillna(-200) # filled and assigned to the original dataset
    print(df_GTA['longitude'].dtype) #printing datatype
except Exception as e:
    print(e)
else:
    print('Missing values filled with -200. Datatype is okay to proceed with longitude column.')
# Out:
# Total Null values in longitude: 4557
# float64
# Missing values filled with -200. Datatype is okay to proceed with longitude column.

# %% [markdown]
# * Analyzing and manipulating 'doubtterr' because it has null values and different datatype

# %%
# Write your code to make your dataset analysis ready.
#Analyzing 'doubterr'
try:
    null_valuecount_to_fill = df_GTA['doubtterr'].isnull().sum() # COunting null values
    df_GTA['doubtterr'] = df_GTA['doubtterr'].fillna(-200) # filled and assigned to the original dataset
    df_GTA['doubtterr'] = df_GTA['doubtterr'].astype(int) #astype used to cange datatype as nemeric
    print(df_GTA['doubtterr'].dtype) #printing datatype
except Exception as e:
    print(e)
else:
    print('Missing values filled with -200. doubtterr column\'s Datatype is changed to int type .')
# Out:
# int64
# Missing values filled with -200. doubtterr column's Datatype is changed to int type .

# %% [markdown]
# * Analyzing and manipulating 'nkill' because it has null values and different datatype

# %%
#Analyzing 'nkill'
try:

    null_valuecount_to_fill = df_GTA['nkill'].isnull().sum() # COunting null values
    print('Total Null values in nkill: ',null_valuecount_to_fill)
    df_GTA['nkill'] = df_GTA['nkill'].fillna(-200) # filled and assigned to the original dataset
    df_GTA['nkill'] = df_GTA['nkill'].astype(int) #astype used to cange datatype as nemeric
    print(df_GTA['nkill'].dtype) #printing datatype
except Exception as e:
    print(e)
else:
    print('Missing values filled with -200. nkill column\'s Datatype is changed to int type .')
# Out:
# Total Null values in nkill:  10313
# int64
# Missing values filled with -200. nkill column's Datatype is changed to int type .

# %% [markdown]
# *   Analyzing and manipulating 'nkillus' because it has 64446 null values and different datatype.

# %%
#Analyzing 'nkillus'
try:
    null_valuecount_to_fill = df_GTA['nkillus'].isnull().sum() # COunting null values
    print('Total Null values in nkillus: ',null_valuecount_to_fill)
    df_GTA['nkillus'] = df_GTA['nkillus'].fillna(-200) # filled and assigned to the original dataset
    df_GTA['nkillus'] = df_GTA['nkillus'].astype(int) #astype used to cange datatype as nemeric
    print(df_GTA['nkillus'].dtype) #printing datatype
except Exception as e:
    print(e)
else:
    print('Missing values filled with -200. nkillus column\'s Datatype is changed to int type .')
# Out:
# Total Null values in nkillus:  64446
# int64
# Missing values filled with -200. nkillus column's Datatype is changed to int type .

# %% [markdown]
# *   Analyzing and manipulating 'nkillter' because it has 66958 null values and different datatype.

# %%
#Analyzing 'nkillter'
try:
    null_valuecount_to_fill = df_GTA['nkillter'].isnull().sum() # COunting null values
    print('Total Null values in nkillter: ',null_valuecount_to_fill)
    df_GTA['nkillter'] = df_GTA['nkillter'].fillna(-200) # filled and assigned to the original dataset
    df_GTA['nkillter'] = df_GTA['nkillter'].astype(int) #astype used to cange datatype as nemeric
    print(df_GTA['nkillter'].dtype) #printing datatype
except Exception as e:
    print(e)
else:
    print('Missing values filled with -200. nkillter column\'s Datatype is changed to int type .')
# Out:
# Total Null values in nkillter:  66958
# int64
# Missing values filled with -200. nkillter column's Datatype is changed to int type .

# %% [markdown]
# * Analyzing and manipulating 'nwound' because it has null values and different datatype.

# %%
# Write your code to make your dataset analysis ready.
#Analyzing 'nwound'
try:
    null_valuecount_to_fill = df_GTA['nwound'].isnull().sum() # Counting null values
    print('Total Null values in nwound: ',null_valuecount_to_fill)
    df_GTA['nwound'] = df_GTA['nwound'].fillna(-200) # filled and assigned to the original dataset
    df_GTA['nwound'] = df_GTA['nwound'].astype(int) #astype used to change datatype as numeric
    print(df_GTA['nwound'].dtype) #printing datatype
except Exception as e:
    print(e)
else:
    print('Missing values filled with -200. nwound column\'s Datatype is changed to int type .')
# Out:
# Total Null values in nwound:  16311
# int64
# Missing values filled with -200. nwound column's Datatype is changed to int type .

# %% [markdown]
# * Analyzing and manipulating 'nwoundus' because it has null values and different datatype.

# %%
# Write your code to make your dataset analysis ready.
#Analyzing 'nwoundus'
try:
    null_valuecount_to_fill = df_GTA['nwoundus'].isnull().sum() # Counting null values
    print('Total Null values in nwoundus: ',null_valuecount_to_fill)
    df_GTA['nwoundus'] = df_GTA['nwoundus'].fillna(-200) # filled and assigned to the original dataset
    df_GTA['nwoundus'] = df_GTA['nwoundus'].astype(int) #astype used to change datatype as numeric
    print(df_GTA['nwoundus'].dtype) #printing datatype
except Exception as e:
    print(e)
else:
    print('Missing values filled with -200. nwoundus column\'s Datatype is changed to int type .')
# Out:
# Total Null values in nwoundus:  64702
# int64
# Missing values filled with -200. nwoundus column's Datatype is changed to int type .

# %% [markdown]
# * Analyzing and manipulating 'nwoundte' because it has null values and different datatype.

# %%
# Write your code to make your dataset analysis ready.
#Analyzing 'nwoundte'
try:
    null_valuecount_to_fill = df_GTA['nwoundte'].isnull().sum() # Counting null values
    print('Total Null values in nwoundte: ',null_valuecount_to_fill)
    df_GTA['nwoundte'] = df_GTA['nwoundte'].fillna(-200) # filled and assigned to the original dataset
    df_GTA['nwoundte'] = df_GTA['nwoundte'].astype(int) #astype used to change datatype as numeric
    print(df_GTA['nwoundte'].dtype) #printing datatype
except Exception as e:
    print(e)
else:
    print('Missing values filled with -200.  nwoundte column\'s Datatype is changed to int type.')
# Out:
# Total Null values in nwoundte:  69143
# int64
# Missing values filled with -200.  nwoundte column's Datatype is changed to int type.

# %% [markdown]
# * Analyzing and manipulating 'propextent' because it has null values and different datatype.

# %%
# Write your code to make your dataset analysis ready.
#Analyzing 'propextent'
try:
    null_valuecount_to_fill = df_GTA['propextent'].isnull().sum() # Counting null values
    print('Total Null values in propextent: ',null_valuecount_to_fill)
    df_GTA['propextent'] = df_GTA['propextent'].fillna(-200) # filled and assigned to the original dataset
    df_GTA['propextent'] = df_GTA['propextent'].astype(int) #astype used to change datatype as numeric
    print(df_GTA['propextent'].dtype) #printing datatype
except Exception as e:
    print(e)
else:
    print('Missing values filled with -200.  propextent column\'s Datatype is changed to int type.')
# Out:
# Total Null values in propextent:  117626
# int64
# Missing values filled with -200.  propextent column's Datatype is changed to int type.

# %% [markdown]
# * Analyzing and manipulating 'propextent_txt' because it has null values and different datatype.

# %%
# Write your code to make your dataset analysis ready.
# Analyzing 'propextent_txt'
try:
    null_valuecount_to_fill = df_GTA['propextent_txt'].isnull().sum() # counting null values
    print('Total Null values in propextent_txt:', null_valuecount_to_fill)
    df_GTA['propextent_txt'] = df_GTA['propextent_txt'].fillna('N/A') # filled and assigned to the original dataset
    print(df_GTA['propextent_txt'].dtype) #printing datatype
except Exception as e:
    print(e)
else:
    print('Missing values filled with N/A. No need to change datatype of propextent_txt')
# Out:
# Total Null values in propextent_txt: 117626
# object
# Missing values filled with N/A. No need to change datatype of propextent_txt

# %% [markdown]
# * Analyzing and manipulating 'ishostkid' because it has null values and different datatype.

# %%
# Write your code to make your dataset analysis ready.
#Analyzing 'ishostkid'
try:
    null_valuecount_to_fill = df_GTA['ishostkid'].isnull().sum() # Counting null values
    print('Total Null values in ishostkid: ',null_valuecount_to_fill)
    df_GTA['ishostkid'] = df_GTA['ishostkid'].fillna(-200) # filled and assigned to the original dataset
    df_GTA['ishostkid'] = df_GTA['ishostkid'].astype(int) #astype used to change datatype as numeric
    print(df_GTA['ishostkid'].dtype) #printing datatype
except Exception as e:
    print(e)
else:
    print('Missing values filled with -200.  ishostkid column\'s Datatype is changed to int type.')
# Out:
# Total Null values in ishostkid:  178
# int64
# Missing values filled with -200.  ishostkid column's Datatype is changed to int type.

# %% [markdown]
# # Note: We replaced -200 in null values of numeric data columns and 'N/A' to text type columns to easily distinguish data what they didn't provide. We will operate by filtering these values(by ignoring rows having -200 and 'N/A')

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# * iyear  : By above founded results these columns dont need to manipulate.
#
# * imonth : By above founded results these columns dont need to manipulate.
#
#
# * iday   :   By above founded results these columns dont need to manipulate.
#
# * idate : It is derived column by iyear, imonth and iday. By above data it is cleared that day or month are unknown, maximum cases are related to government employess. So we take decision to not to drop and fill missing values.
#
# * country,country_txt : By above founded results these columns dont need to manipulate.
#
# * region,region_txt  : By above founded results these columns dont need to manipulate.
#
# * city  : We filled missing values as N/A. And changed datatype to string.
#
#
# * latitude : We filled missing values as -200. And changed datatype to string.
#
#
# * longitude : We filled missing values as -200. And changed datatype to string.

# %% [markdown]
# *   crit1, crit2, crit3 : By above founded results these columns dont need to manipulate.
# *   doubterr : We filled missing values as -9. And changed datatype to int64.
# *   success  : By above founded results this column dont need to manipulate.
# *   suicide : By above founded results this column dont need to manipulate.
# *   attacktype1,attacktype1_txt : dont need to manipulate.
# *   targtype1_txt : Don't need to manipulate.
# *   individual : Don't need to manipulate.
# *   targtype1,weaptype1_txt : Don't need to manipulate.
# *   nkill : We filled missing values as 0. And changed datatype to int64.
# *   nkillter : We filled missing values as 0. And changed datatype to int64.

# %% [markdown]
# *   nwound : We filled missing values as 0 and changed datatype to int64.
# *   nwoundus : We filled missing values as 0 and changed datatype to int64.
# *   nwoundte :  We filled missing values as 0 and changed datatype to int64.
# *   property : No need to manipulate.
# *   propextent : We filled missing values as 0 and changed datatype to int64.
# *   propextent_txt : We filled missing values as Unknown and changed datatype to string.
# *   ishostkid : We filled missing values as -9 and changed datatype to int64.
# *   INT_LOG : No need to manipulate.
# *   INT_IDEO : No need to manipulate.
# *   INT_MISC : No need to manipulate.
# *   INT_ANY : No need to manipulate.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 - Countplot

# %%
# Chart - 1 visualization code
fig= plt.subplots(figsize=(11, 7))
ax = sbn.countplot(x=df_GTA["iyear"]) # used seaborn countplot
# Loop to give annotation
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()),  ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points',rotation=90)

plt.xlabel('Year') #xlable
plt.title('Count plot of incidents each year')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We choose countplot to show number of attack incidents with respect to years. It is used to display Univariate Analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# By above chart we observed that, In the year 2014 the incidends are in peaks followed by 2015, 2016,2013,2017,2012.
# The lowest incident recorded in year 1971 followed by 1973,1972,1974.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The data shown us incidents are in -ve growth which is good.

# %% [markdown]
# #### Chart - 2 -Countplot

# %%
# Chart - 2 visualization code
fig= plt.subplots(figsize=(7, 5))
ax = sbn.countplot(data =df_GTA, x=df_GTA["country_txt"],order=df_GTA.country_txt.value_counts().iloc[:10].index) # used seaborn countplot
# Loop to give annotation
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()),  ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points',rotation=90)
plt.xlabel('Country')
plt.title('Top 10 Country having most incidents')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We chose Countplot to show Univariate Analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Chart shows the Top 10 country which having most incident takes place till 2017.
# Iraq is in the top, followed as Pakistan, Afganistan, India, Colombia, so on...

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The chart shows, Contries with negetive growth. Each counties getting lower incident count as we go from left to right.

# %% [markdown]
# #### Chart - 3 - Countplot

# %%
# Chart - 3 visualization code
fig= plt.subplots(figsize=(7, 5))
ax = sbn.countplot(data =df_GTA, x=df_GTA["country_txt"],order=df_GTA.country_txt.value_counts().iloc[:-21:-1].index)
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()),  ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points',rotation=90)
plt.xlabel('Country')
plt.title('Top 20 Country having least incidents')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We choose countplot to show number of attack incidents with respect to Countries. It is used to display Univariate Analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Chart shows the Top 10 country which having least incident takes place till 2017.
# Antigua and Barbuda is in the top, followed as Andorra, Sout Vietnam, Wallis and Futuna, International, so on...

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The chart shows, Countries with negetive growth with respect to number of attacks are in increasing order by country. Each countries getting higher incident count as we go from left to right.

# %% [markdown]
# #### Chart - 4 - Countplot

# %%
# Chart - 4 visualization code
rslt = df_GTA[df_GTA["city"] != 'Unknown'] # Filtering Unknown data
fig= plt.subplots(figsize=(7, 7))
ax = sbn.countplot(data =rslt, x=rslt["city"],order=rslt.city.value_counts().iloc[:20].index)
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()),  ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points',rotation=90)
plt.xlabel('City')
plt.title('Top 20 Cities having most incidents')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We choose countplot to show number of attack incidents with respect to cities. It is used to display Univariate Analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows, Cities with negetive growth (incident count wise). Each city listed getting lower incident count as we go from left to right

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The chart shows, Cites with negetive growth with respect to number of attacks are in decreasing order by Cities. Each Cities getting lower incident count as we go from left to right. This isight also will helpfull to reduce terrerism activity.

# %% [markdown]
# #### Chart - 5 - Countplot

# %%
# Chart - 5 visualization code
rslt = df_GTA[df_GTA["region_txt"] != 'Unknown']
fig= plt.subplots(figsize=(7, 7))
ax = sbn.countplot(data =rslt, x=rslt["region_txt"],order=rslt.region_txt.value_counts().iloc[:5].index)
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()),  ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points',rotation=90)
plt.xlabel('Region')
plt.title('Top 5 Region having most incidents')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We choose countplot to show number of attack incidents with respect to regions. It is used to display Univariate Analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Top regions having attack incidents are Middle East and North Africa folowed by South Africa, South America, Sub-Saharan Africa, Western Europe.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The chart shows, Regions with negetive growth with respect to number of attacks are in decreasing order by Region. Each Region getting lower incident count as we go from left to right. This isight also will helpfull to reduce terrerism activity.

# %% [markdown]
# #### Chart - 6 - Countplot

# %%
# Chart - 6 visualization code
success_count = df_GTA['success'].count()
ax,fig= plt.subplots(figsize=(5,5))
ax = sbn.countplot(data=df_GTA,x='success')
plt.title('Success Rate of Incidents')
plt.xlabel('Success Rate')
for p in ax.patches:
    # ax.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()),  ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points',rotation=90)
    ax.annotate(format((p.get_height()/success_count)*100, '.2f')+'%', (p.get_x() + p.get_width() / 2., p.get_height()),  ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We choose countplot to show Success percentage of attack incidents with respect to total data provided from 1976 to 2017. It is used to display Univariate Analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows Success rate of attack. It clears that 89.96 % of attacks are success in damaging the targets.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This insight leads to negetive growth in the sense of protecting peoples and properties by government rules and policies of criminal activity.

# %% [markdown]
# #### Chart - 7 - Line Plot

# %%
# Chart - 7 visualization code
yearly_attacks_region = df_GTA.groupby(['iyear', 'region_txt']).agg(counts_region_txt=('region_txt','count'))
fig = plt.subplots()
ax = sbn.lineplot(data = yearly_attacks_region,x='iyear',hue='region_txt',y='counts_region_txt')
plt.xlabel('Years')
plt.title('Trend of incidents in regions by yearwise ')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We choose lineplot to show trends with respect to years and region wise. It is used to display Multivariate Analysis(with hue).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Chart shows the data by year and region wise trend.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The chart shows positive growth in attack incicidents after year 2000. Then South Asia overtaken by Middle East and North Africa by number of attack incidents.

# %% [markdown]
# #### Chart - 8 - Barplot

# %%
# Chart - 8 visualization code

top_most_incident_country = df_GTA['country_txt'].value_counts(sort=True).head(10) # Getting top 10 Country having maximum incidents
top_most_incident_country = np.array(top_most_incident_country.index) # Storing as numpy array

# Filtering Unknown attacktype for accuracy of result
rslt = df_GTA[(df_GTA['attacktype1_txt'] != 'Unknown') & (df_GTA['country_txt'].isin(top_most_incident_country))]

# Extacting data to show Counts by grouping country and attack type
rslt = rslt.groupby(['country_txt','attacktype1_txt'],as_index=False).agg(count_attacktype1_txt=('attacktype1_txt','count')).sort_values('count_attacktype1_txt',ascending=False)
# rslt
fig= plt.subplots(figsize=(15,5))
ax = sbn.barplot(data=rslt,x='country_txt',y='count_attacktype1_txt',hue='attacktype1_txt',width=1)
plt.xlabel('Country')
plt.ylabel('Count')
plt.title('Bar Plot to show distrubution of attack type')
plt.xticks(rotation=45)
# sbn.despine(offset=10, trim=True)
for p in ax.patches:
    ax.annotate(format(p.get_height(),'.0f'), (p.get_x() + p.get_width() / 2., p.get_height()),  ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points',rotation=90)
plt.legend(title='Attack Types')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We chose this type of chart to show Multivariate Analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Top 10 Contries (As we saw in earlier charts)
# *   Mostly attacktype planned with Bombing / Explosion, Armed Assault, Assassination
# *   Hijacking is also preffered by attackers

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This insights will very helpfull to which domain should be taken care off

# %% [markdown]
# #### Chart - 9 Barplot

# %%
# Chart - 9 visualization code
# Getting top 10 regions having maximum incidents
top_most_incident_country = df_GTA['region_txt'].value_counts(sort=True).head(10)
top_most_incident_country = np.array(top_most_incident_country.index)

# Filtering Unknown attacktype for accuracy of result having list of region
rslt = df_GTA[(df_GTA['attacktype1_txt'] != 'Unknown') & (df_GTA['region_txt'].isin(top_most_incident_country))]

# Extacting data to show Counts by grouping country and attack type
rslt = rslt.groupby(['region_txt','attacktype1_txt'],as_index=False).agg(count_attacktype1_txt=('attacktype1_txt','count')).sort_values('count_attacktype1_txt',ascending=False)

# Barplot Visualization code
fig= plt.subplots(figsize=(15,5))
ax = sbn.barplot(data=rslt,x='region_txt',y='count_attacktype1_txt',hue='attacktype1_txt',width=1)
plt.xlabel('Region')
plt.ylabel('Count')
plt.title('Bar Plot to show distrubution of attack type Region dwise')
plt.xticks(rotation=45)
for p in ax.patches:
    ax.annotate(format(p.get_height(),'.0f'), (p.get_x() + p.get_width() / 2., p.get_height()),  ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points',rotation=90)
plt.legend(title='Attack Types')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To show Multivariate Analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Top 10 Regions (As we saw in earlier charts)
# *   Mostly attacktype planned with Bombing / Explosion, Armed Assault, Assassination
# *   Hijacking is also preffered by attackers

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This insights will very helpfull to which domain should be taken care off.

# %% [markdown]
# #### Chart - 10 - Barplot

# %%
# Removing Unavailable data
rslt = df_GTA[df_GTA['nkill'] != -200]
# Grouping data for visualization with order
rslt = rslt.groupby(['country_txt'],as_index=False).agg(total_no_of_nkill=('nkill','sum'))
rslt = rslt.sort_values('total_no_of_nkill',ascending=False).head(30)

# Chart - 10 visualization code
fig= plt.subplots(figsize=(15,5))
ax = sbn.barplot(data=rslt,x='country_txt',y='total_no_of_nkill')
plt.xlabel('Country')
plt.ylabel('Count')
plt.title('Count of Total deaths in Attacks (Including terrorists and Public)')
plt.xticks(rotation=90)
# Annotation Code
for p in ax.patches:
    ax.annotate(format(p.get_height(),'.0f'), (p.get_x() + p.get_width() / 2., p.get_height()),  ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points',rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We choose barplot to show number of attack incidents with respect to country. It is also used to display Univariate Analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# By available dataset the insights have found that Iraq is in the top. Followed by Afganisthan, pakistan, Nigeria, India and so on.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Till now it is also cleared, That Iraq is in the top most dangerous Country.

# %% [markdown]
# #### Chart - 11 - Barplot

# %%
# Chart - 11 visualization code
rslt = df_GTA[['nkillter','iyear']]
rslt = rslt[rslt['nkillter']!=-200]
rslt = rslt.groupby(['iyear'],as_index=False).agg(Total_nkillter=('nkillter','sum'))

fig= plt.subplots(figsize=(15,5))
ax = sbn.barplot(data=rslt,x='iyear',y='Total_nkillter')
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Number of terrorist killed (Year wise)')
plt.xticks(rotation=90)
# sbn.despine(offset=10, trim=True)
for p in ax.patches:
    ax.annotate(format(p.get_height(),'.0f'), (p.get_x() + p.get_width() / 2., p.get_height()),  ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points',rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We choose barplot to show number of terrerist killed in attack incidents with respect to years. It is also used to display Univariate Analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# By chart it is clearly being observed that after 2011 the terrerist are killed by taking actions on terrerist issue.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We found that it is now decreasing again after 2016

# %% [markdown]
# #### Chart - 12 - Barplot

# %%
# Chart - 12 visualization code
rslt = df_GTA[['nkill','iyear']]
rslt = rslt[rslt['nkill']!=-200]
rslt = rslt.groupby(['iyear'],as_index=False).agg(Total_nkill=('nkill','sum'))

fig= plt.subplots(figsize=(15,5))
ax = sbn.barplot(data=rslt,x='iyear',y='Total_nkill')
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Number of Fatalities (Year wise includes all victims and attackers)')
plt.xticks(rotation=90)
# sbn.despine(offset=10, trim=True)
for p in ax.patches:
    ax.annotate(format(p.get_height(),'.0f'), (p.get_x() + p.get_width() / 2., p.get_height()),  ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points',rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We choose barplot to show number of terrerist killed in attack incidents with respect to years. It is also used to display Univariate Analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Max number of fatalities are taken place in year 2014. followed by 2015,2016,2017,2013.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes . Insights having negetive growth because it is not good for the country reputation or from any other perspective. It should be controlled by taking action on criminalism.

# %% [markdown]
# #### Chart - 13 - Scatter Plot

# %%
# Chart - 13 visualization code
rslt = df_GTA[df_GTA['nkill']!=200].sort_values('nkill',ascending=False).head(20)
print('Summary of Top 20 incident by Total Number of killed :')
print(rslt[['country_txt','region_txt','city','nkill','idate','attacktype1_txt','latitude','longitude']].to_string())

fig= plt.subplots()
ax = sbn.scatterplot(data=rslt,x='longitude',y='latitude',hue='city',size='nkill')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.title('Number of fatalities (directional coordinate wise) with size and city ')
plt.xlabel('longitude')
plt.title('Size distribution with longitude and latiitude of city')
plt.show()
# Out:
# Summary of Top 20 incident by Total Number of killed :
#                              country_txt                  region_txt              city  nkill      idate                      attacktype1_txt   latitude  longitude
# 133518                              Iraq  Middle East & North Africa            Tikrit   1570 2014-06-12          Hostage Taking (Kidnapping)  34.621521  43.668377
# 73126                      United States               North America     New York City   1384 2001-09-11                            Hijacking  40.697132 -73.931351
# 73127                      United States               North America     New York City   1383 2001-09-11                            Hijacking  40.697132 -73.931351
# 55934                             Rwanda          Sub-Saharan Africa            Gikoro   1180 1994-04-13                        Armed Assault  -1.932787  30.332456
# 136283                              Iraq  Middle East & North Africa            Sinjar    953 2014-08-03          Hostage Taking (Kidnapping)  36.319386  41.861473
# 133225                              Iraq  Middle East & North Africa            Badush    670 2014-06-10                        Armed Assault  36.407394  42.964626
# 179671                           Somalia          Sub-Saharan Africa         Mogadishu    588 2017-10-14                    Bombing/Explosion   2.059819  45.326115
# 76347                              Nepal                  South Asia  Dhading district    518 2004-03-21                        Armed Assault  27.959441  84.895897
# 136746                             Syria  Middle East & North Africa           Unknown    517 2014-08-19          Hostage Taking (Kidnapping)  35.959198  38.998018
# 170198                             Syria  Middle East & North Africa           Palmyra    433 2016-12-10          Hostage Taking (Kidnapping)  34.558525  38.293671
# 6629                                Iran  Middle East & North Africa            Abadan    422 1978-08-19       Facility/Infrastructure Attack  30.345997  48.287136
# 136561                              Iraq  Middle East & North Africa              Kojo    400 2014-08-15          Hostage Taking (Kidnapping)  36.177341  41.910160
# 90401   Democratic Republic of the Congo          Sub-Saharan Africa              Tora    400 2009-01-17       Facility/Infrastructure Attack   3.292111  29.168137
# 31595                         Mozambique          Sub-Saharan Africa           Homoine    388 1987-07-18                        Armed Assault -23.738177  34.974707
# 164327                              Iraq  Middle East & North Africa           Baghdad    383 2016-07-03                    Bombing/Explosion  33.303566  44.371773
# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - *16* - Scatter PLot

# %%
rslt = df_GTA[df_GTA['nkillus']!=200].sort_values('nkillus',ascending=False).head(20)
print('Summary of Number of US Citizen killed :')
print(rslt[['country_txt','region_txt','city','nkillus','idate','attacktype1_txt','latitude','longitude']].to_string())

fig= plt.subplots()
ax = sbn.scatterplot(data=rslt,x='longitude',y='latitude',hue='city',size='nkillus')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.title('Number of fatalities (directional coordinate wise) with size and city ')
plt.xlabel('longitude')
plt.title('latitude')
plt.show()
# Out:
# Summary of Number of US Citizen killed :
#            country_txt                  region_txt             city  nkillus      idate                      attacktype1_txt    latitude   longitude
# 73126    United States               North America    New York City     1360 2001-09-11                            Hijacking   40.697132  -73.931351
# 73127    United States               North America    New York City     1327 2001-09-11                            Hijacking   40.697132  -73.931351
# 20075          Lebanon  Middle East & North Africa           Beirut      241 1983-10-23                    Bombing/Explosion   33.888523   35.503513
# 36669   United Kingdom              Western Europe        Lockerbie      189 1988-12-21                    Bombing/Explosion   55.120154   -3.355942
# 73128    United States               North America        Arlington      182 2001-09-11                            Hijacking   38.878742  -77.100006
# 59037    United States               North America    Oklahoma City      168 1995-04-19                    Bombing/Explosion   35.472015  -97.520354
# 67533          Algeria  Middle East & North Africa       Sidi Hamed       60 1998-01-11                    Bombing/Explosion   36.744530    3.052680
# 67534          Algeria  Middle East & North Africa  Haouch Sahraoui       60 1998-01-11                    Bombing/Explosion -200.000000 -200.000000
# 163568   United States               North America          Orlando       44 2016-06-12  Hostage Taking (Barricade Incident)   28.519601  -81.376794
# 73129    United States               North America      Shanksville       38 2001-09-11                            Hijacking   40.018464  -78.907197
# 25532           Canada               North America          Toronto       31 1985-06-23                    Bombing/Explosion   43.666667  -79.416667
# 2138             Italy              Western Europe             Rome       30 1973-12-17  Hostage Taking (Barricade Incident)   41.890961   12.490069
# 77313             Iraq  Middle East & North Africa            Mosul       20 2004-12-21                    Bombing/Explosion   36.354145   43.143570
# 62724     Saudi Arabia  Middle East & North Africa          Dhahran       19 1996-06-25                    Bombing/Explosion   26.266220   50.150466
# 70819         Pakistan                  South Asia            Okara       17 2000-08-13                    Bombing/Explosion   30.807929   73.450466
# 18572          Lebanon  Middle East & North Africa           Beirut       17 1983-04-18                    Bombing/Explosion   33.888523   35.503513
# 71173            Yemen  Middle East & North Africa             Aden       17 2000-10-12                    Bombing/Explosion   12.825647   44.846416
# 77293             Iraq  Middle East & North Africa            Baiji       16 2004-12-11                        Armed Assault   34.924850   43.491413
# 116173   United States               North America             West       15 2013-04-17       Facility/Infrastructure Attack   31.816677  -97.087902
# 156150   United States               North America   San Bernardino       15 2015-12-02                    Bombing/Explosion   34.075770 -117.277924

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Choosed Scatter plot to show M- Multivariate Analysis

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   By Above visualization we found the two biggest incident in almost same co-ordinate.
#
# *   The September 11 attacks, commonly known as 9/11, were four coordinated suicide terrorist attacks carried out by al-Qaeda against the United States on Tuesday, September 11, 2001. That morning, 19 terrorists hijacked four commercial airliners scheduled to travel from the New England and Mid-Atlantic regions of the East Coast to California. The hijackers crashed the first two planes into the Twin Towers of the World Trade Center in New York City, two of the five tallest buildings in the world at the time.
#
# Information source - https://en.wikipedia.org/wiki/September_11_attacks

# %% [markdown]
# #### Chart - 17 - Scatter PLot

# %%
rslt = df_GTA[df_GTA['nkillter']!=200].sort_values('nkillter',ascending=False).head(20)
print('Summary of Number of Tererist Citizen killed :')
print(rslt[['country_txt','region_txt','city','nkillter','idate','attacktype1_txt','latitude','longitude']].to_string())

fig= plt.subplots()
ax = sbn.scatterplot(data=rslt,x='longitude',y='latitude',hue='city',size='nkillter')
sbn.color_palette("husl", 9)
plt.title('Number of fatalities (directional coordinate wise) with size and city ')
plt.xlabel('longitude')
plt.title('latitude')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.show()
# Out:
# Summary of Number of Tererist Citizen killed :
#                              country_txt                  region_txt              city  nkillter      idate              attacktype1_txt   latitude  longitude
# 76347                              Nepal                  South Asia  Dhading district       500 2004-03-21                Armed Assault  27.959441  84.895897
# 136746                             Syria  Middle East & North Africa           Unknown       346 2014-08-19  Hostage Taking (Kidnapping)  35.959198  38.998018
# 170198                             Syria  Middle East & North Africa           Palmyra       301 2016-12-10  Hostage Taking (Kidnapping)  34.558525  38.293671
# 67589                          Sri Lanka                  South Asia       Kilinochchi       300 1998-02-01                      Unknown   9.380289  80.377000
# 166173                       South Sudan          Sub-Saharan Africa             Pajut       250 2016-08-19                Armed Assault   7.181962  32.356095
# 144897                           Nigeria          Sub-Saharan Africa           Gambaru       207 2015-02-24                Armed Assault  12.359468  14.210929
# 128765                           Nigeria          Sub-Saharan Africa         Maiduguri       207 2014-03-14                Armed Assault  11.840929  13.141459
# 137852                           Nigeria          Sub-Saharan Africa           Konduga       201 2014-09-17                Armed Assault  11.655408  13.412932
# 141472                          Cameroon          Sub-Saharan Africa          Am Chide       180 2014-12-11                Armed Assault  11.236522  14.126195
# 147248                             Niger          Sub-Saharan Africa           Karamga       156 2015-04-25                Armed Assault  14.015000  13.378458
# 112375  Democratic Republic of the Congo          Sub-Saharan Africa           Unknown       151 2012-11-15                      Unknown  -1.131175  29.254875
# 173425                              Iraq  Middle East & North Africa           Unknown       151 2017-03-29                      Unknown  36.388819  42.874607
# 131794                           Nigeria          Sub-Saharan Africa            Garawa       151 2014-05-13                Armed Assault  11.929978  14.343351
# 142765                          Cameroon          Sub-Saharan Africa          Kolofata       143 2015-01-12                Armed Assault  11.162543  14.013976
# 167692                       Afghanistan                  South Asia            Kunduz       140 2016-10-03                Armed Assault  36.705776  68.877060
# 151661                           Ukraine              Eastern Europe     Starohnativka       136 2015-08-10            Bombing/Explosion  47.541172  37.780678
# 143671                          Cameroon          Sub-Saharan Africa           Fotokol       123 2015-01-29            Bombing/Explosion  12.379026  14.224362
# 141661                          Cameroon          Sub-Saharan Africa          Am Chide       116 2014-12-17            Bombing/Explosion  11.236522  14.126195
# 133185                             Sudan          Sub-Saharan Africa           Alatmur       110 2014-06-09            Bombing/Explosion  10.900763  30.069372
# 163475                           Somalia          Sub-Saharan Africa            Halgan       102 2016-06-09            Bombing/Explosion   4.210529  45.560490

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We choose scatterplot to show the total no of nkillter with respect to city(Univariate).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# By above chart and table we observed that most terrorist killed in Dhading district

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We found most of all terrorist are killed in Dhading district It should be controlled by taking action on criminalism.

# %% [markdown]
# # Chart-18

# %%
#### Chart-19-visualization code

doubtterr_count = df_GTA[df_GTA['doubtterr'] != -200]
ax,fig= plt.subplots(figsize=(5,5))
ax = sbn.countplot(data=doubtterr_count,x='doubtterr')
plt.xlabel('0 - No Doubt, 1- Doubt') #xlable
plt.title('Act of terrerism')
for p in ax.patches:
    # ax.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()),  ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points',rotation=90)
     ax.annotate(format((p.get_height()/success_count)*100, '.2f')+'%', (p.get_x() + p.get_width() / 2., p.get_height()),  ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# We choose countplot to show univariate analysis percentage of terrerism act f

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * By above obeservation 76.45% no doubt. It is a terrorist act
# * And 15.96% doubt

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, we clear about the act of terrorism this insights very helpful to take action on terrorism

# %% [markdown]
# # Chart-19 - Countplot

# %%
#### Chart-20
vicinity_count = df_GTA['vicinity'].count()
ax,fig= plt.subplots(figsize=(5,5))
ax = sbn.countplot(data=df_GTA,x='vicinity')
plt.xlabel('0 = In vicinity, 1 = Not in vicinity, -9 = Unknown')
plt.title('%age of The incident occurred in the immediate vicinity of the city')
for p in ax.patches:
    # ax.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()),  ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points',rotation=90)
    ax.annotate(format((p.get_height()/vicinity_count)*100, '.2f')+'%', (p.get_x() + p.get_width() / 2., p.get_height()),  ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# We choose countplot to show the incident occured in immediate vicinity of city or incident occured in city itself.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * By above observation 92.98% the incident occured in city.
# * And 7.00% incident occured in immediate vicinity of the city

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# The business objective of the World Terrorism Database (WTD) is to provide a comprehensive and reliable source of data and analysis on global terrorism incidents. The database serves the following business objectives:
#
# Data Provision: The WTD aims to collect, curate, and provide accurate and up-to-date data on terrorist incidents worldwide. By maintaining a comprehensive and reliable database, the objective is to serve as a trusted resource for researchers, policymakers, security agencies, and other stakeholders seeking information on terrorism trends, patterns, and characteristics.
#
# Analysis and Insights: The WTD conducts in-depth analysis and exploration of the collected data to uncover meaningful insights and trends related to global terrorism. By employing various analytical techniques, the objective is to provide valuable insights into the factors influencing terrorism, temporal and spatial patterns, attack types, tactics, and the impact of terrorism. These insights contribute to a better understanding of terrorism dynamics and aid in the development of effective counter-terrorism strategies.
#
# Decision Support: The WTD aims to support evidence-based decision-making by providing timely and accurate information to policymakers, security agencies, and organizations involved in counter-terrorism efforts. The objective is to help stakeholders make informed decisions, allocate resources effectively, and develop targeted interventions to prevent and mitigate the impact of terrorism.
#
# Risk Assessment: By analyzing global terrorism trends and patterns, the WTD contributes to risk assessment and threat analysis. The objective is to help businesses, governments, and organizations assess the potential risks and vulnerabilities related to terrorism in specific regions or sectors. This information enables them to develop risk management strategies and implement appropriate security measures.
#
# Collaboration and Partnerships: The WTD seeks to foster collaboration and partnerships among researchers, policymakers, and security agencies. The objective is to create a platform for sharing knowledge, exchanging best practices, and promoting international cooperation in combating terrorism. Collaborative efforts can lead to more effective strategies, improved data quality, and a broader understanding of the complex dynamics of terrorism.
#
# Overall, the business objective of the World Terrorism Database is to provide accurate, comprehensive, and insightful data and analysis to support decision-making, risk assessment, and counter-terrorism efforts globally. By fulfilling these objectives, the WTD aims to contribute to a safer and more secure world by combating terrorism effectively.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The Exploratory Data Analysis (EDA) conducted on the Global Terrorism Dataset provided significant insights into trends and patterns in global terrorism from 1970 through 2017. With the help of the Python libraries Pandas, Matplotlib, Seaborn, and NumPy, we were able to handle, visualize and interpret complex data related to terrorist activities.
#
# Through this analysis, we identified trends over time, regional hotspots, dominant terrorist groups, and preferred modes of attacks. All these findings are crucial for devising effective counter-terrorism strategies and interventions.
#
# The process underscored the power of data-driven decision-making. By using EDA, we were able to transform raw data into meaningful insights. For instance, understanding that certain regions are more prone to terrorist attacks or that specific terrorist groups are more active allows security agencies and policymakers to allocate resources more efficiently, thereby potentially saving lives and property.
#
# However, while this data analysis provides a robust foundation, it's important to acknowledge that addressing terrorism requires more than just understanding past data. It necessitates a comprehensive approach that includes current intelligence, geopolitical considerations, and on-the-ground realities.
#
# To conclude, this project demonstrates the potential of data analysis in informing and shaping counter-terrorism efforts. It provides a useful starting point for further study and action, emphasizing the importance of continuous data collection, analysis, and interpretation in tackling global security challenges like terrorism.
#
#
# ---
#
#
#
#
#
#
# ### **Need to keep in mind to achieve Business Objective**.
#
# ##  **Highlights** :
# ## During the period of 1970-2017, the following highlights emerge regarding the most attacked countries and regions based on the World Terrorism Database:
#
# **Most Attacked Countries** :
#
# **Iraq**:
# * Iraq witnessed a significant number of terrorist incidents during this period, particularly after the 2003 invasion and the subsequent rise of ISIS.
# * The country faced numerous bombings, armed assaults, and attacks targeting civilians, security forces, and infrastructure.
#
# * Sectarian conflicts, insurgencies, and political instability contributed to the high levels of violence.
#
# **Afghanistan** :
#
# * Afghanistan experienced a prolonged period of conflict, making it highly vulnerable to terrorist attacks.
#
# * The country faced a substantial number of suicide bombings, armed assaults, and attacks targeting government institutions, security forces, and civilians.
#
# * Ongoing insurgency, the presence of Taliban, and the influence of extremist groups contributed to the violence.
#
# **Pakistan** :
# * Pakistan witnessed a significant rise in terrorist incidents during this period, including suicide bombings, sectarian violence, and attacks on religious and minority groups.
#
# * The country faced challenges from groups like Tehrik-i-Taliban Pakistan (TTP) and extremist factions seeking to destabilize the country.
#
# * Attacks targeted civilians, security forces, religious sites, and government institutions.
#
# **India** :
# * India experienced a considerable number of terrorist incidents, particularly related to separatist movements in regions like Jammu and Kashmir.
#
# * The country faced bombings, armed attacks, and incidents of cross-border terrorism.
#
# * Attacks targeted security forces, public spaces, and religious sites.
#
# **Colombia** :
# * Colombia endured a prolonged armed conflict involving various insurgent groups like the Revolutionary Armed Forces of Colombia (FARC) and National Liberation Army (ELN).
#
# * The country faced bombings, armed assaults, kidnappings, and attacks on infrastructure, security forces, and civilians.
#
# * The conflict was fueled by political, social, and drug trafficking-related motivations.
#
# **Most Attacked Region**:
#
# The Middle East and North Africa (MENA) region:
#
# * The MENA region witnessed a significant number of terrorist incidents during the specified period.
#
# * Ongoing conflicts, sectarian tensions, and the rise of extremist groups contributed to the high levels of violence.
#
# * Countries like Iraq, Syria, Lebanon, and Yemen were particularly affected by terrorism during this period.
#
# These highlights shed light on the countries and regions that experienced a high incidence of terrorism between 1970 and 2017.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
